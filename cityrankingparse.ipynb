# %%
import fitz  # PyMuPDF
import pandas as pd

# %%
df.pd

# %%
doc = fitz.open('2020年度中国展览数据统计报告.pdf')
page = doc.load_page(140)
text=page.get_text()
text
# Out:
# '2 0 2 0 中 国 展 览 数 据 统 计 报 告\n141\n表 1\n2020 年中国城市展览业发展综合指数评价排序\n序\n号\n城市\n展览\n数量\n(场)\n展览\n总面积\n（万平\n方米）\n境内\n办展\n主体\n（个）\n境外\n展览\n数量\n（场）\n境外\n办展\n主体\n（个）\n展馆\n数量\n（座）\n展览\n面积\n（万平\n方米）\n政府\n主管\n机构\n（个）\nIAEE\n组织\n成员\n（个）\nIAEE\n个人\n成员\n（位）\nUFI\n成员\n（个）\nUFI\n认证\n项目\n（个）\nTOP3\n项目\n（个）\nTOP\n100\n项目\n（个）\n本科\n院校\n（个）\n专科\n院校\n（个）\n公众\n公司\n（家）\n线 上\n展 会\n数 量\n（场）\n综合\n指数\n（分值）\n1\n上海\n305\n977.6\n242\n-\n-\n9\n98\n6\n10\n53\n29\n25\n67\n30\n8\n10\n3\n133\n353.8\n2\n广州\n134\n636.0\n111\n1\n4\n5\n49\n3\n1\n3\n18\n10\n34\n11\n8\n18\n1\n55\n185.7\n3\n深圳\n99\n460.5\n22\n-\n-\n2\n61\n2\n3\n41\n14\n17\n33\n17\n1\n-\n2\n32\n160.3\n4\n北京\n89\n178.0\n181\n1\n1\n9\n38\n6\n6\n51\n28\n9\n11\n3\n7\n8\n8\n44\n137.4\n5\n青岛\n177\n249.6\n67\n-\n-\n4\n60\n2\n1\n7\n4\n7\n14\n4\n1\n2\n-\n20\n89.4\n6\n济南\n87\n234.8\n44\n-\n-\n4\n31\n3\n-\n-\n9\n15\n17\n1\n4\n3\n-\n9\n85.1\n7\n南京\n238\n244.8\n58\n-\n-\n4\n16\n4\n-\n-\n7\n3\n10\n1\n1\n1\n-\n40\n81.9\n8\n成都\n34\n154.0\n44\n-\n-\n3\n33\n6\n7\n40\n12\n13\n9\
# ...

# %% [markdown]
# #model
# text='序号\n城市\n展览数量\n展总面积\n境内办展主体\n境外展览数量\n境外办展主体\n展馆数量\n展馆面积\n政府社团研究机构\n会展研究会员数\nIAEE组织成员(人)\nUFI成员(人)\nUFI认证项目\nTOP3项目\nTOP100项目\n本科院校\n专科院校\n公众公司家\n线上展会数量\n综合指数\n1\n北京\n5\n26.00\n187\n0\n0\n15\n71.19\n10\n185\n3\n29\n26\n3\n1\n7\n8\n8\n7\n260.32\n2\n上海\n17\n103.22\n51\n0\n0\n9\n97.70\n10\n68\n4\n31\n26\n7\n5\n8\n10\n2\n0\n142.19\n3\n广州\n76\n329.73\n68\n1\n1\n7\n70.68\n11\n25\n1\n18\n14\n25\n12\n9\n22\n1\n0\n131.44\n4\n深圳\n39\n305.22\n46\n1\n1\n8\n75.50\n3\n16\n1\n18\n16\n24\n13\n1\n0\n2\n8\n110.37\n5\n成都\n36\n164.80\n33\n0\n0\n7\n35.62\n8\n32\n7\n11\n10\n11\n7\n8\n9\
-\n-\n-\n-\n14.1\n31\n兰州\n21\n21.7\n30\n-\n-\n1\n4\n5\n6\n-\n-\n-\n-\n-\n1\n-\n-\n-\n-\n-\n14.6\n32\n呼和浩特\n19\n46.1\n4\n-\n-\n2\n5\n2\n1\n-\n-\n-\n2\n-\n1\n4\n-\n-\n-\n-\n11.9\n33\n乌鲁木齐\n12\n14.3\n3\n-\n-\n1\n2\n4\n4\n1\n1\n-\n-\n-\n2\n2\n-\n-\n-\n-\n9.7\n34\n银川\n9\n15.5\n12\n-\n-\n1\n9\n3\n2\n1\n-\n-\n-\n-\n-\n2\n-\n-\n-\n-\n7.5\n35\n西宁\n11\n22.9\n8\n-\n-\n1\n3\n3\n-\n-\n-\n-\n-\n-\n-\n-\n-\n-\n-\n-\n4.9\n36\n拉萨\n2\n2.5\n1\n-\n-\n3\n3\n-\n-\n-\n-\n-\n-\n-\n-\n-\n-\n-\n-\n-\n1.2\n'

# %%
# Splitting the text by new lines
lines = t1.split('\n')

# Assuming the structure is known and each row has a fixed number of elements
num_elements_per_row = 23  # Adjust based on your specific table structure
rows = [lines[i:i + num_elements_per_row] for i in range(0, len(lines), num_elements_per_row)]

# Create a DataFrame
df = pd.DataFrame(rows[1:], columns=rows[0])  # Using the first row as headers
df2021=df.dropna()
df2021
# Cleaning and converting data types as necessary
#df['城市'] = df['城市'].str.strip()  # Example of cleaning city names
#df['展览数量'] = pd.to_numeric(df['展览数量'])
# Out:
#     序号    城市 展览数量   展总面积 境内办展主体 境外展览数量 境外办展主体 展馆数量 展馆面积 政府社团研究机构  ... UFI认证项目  \
# 0    1    上海  231  1,086    232      -      -    8   79        9  ...      29
# 1    2    北京  124  533.4    171      5      1    9   33        9  ...       5
# 2    3    广州  209    684    111      -      -    5   49       10  ...      10
# 3    4    深圳  105    503     22      -      -    3   61        3  ...      18
# 4    5    成都  242    427     44      -      -    3   33        8  ...      13
# 5    6    济南  106  189.5     44      5      2    5   19        5  ...      19
# 6    7    杭州   38  137.3     50      4      2    7   31       11  ...       2
# 7    8    重庆   81  208.8     69      -      -    3   31        4  ...       3
# 8    9    长沙  109  199.6     57      -      -    4   16       10  ...       4
# 9   10    南京  161  163.1     58      -      -    4   16        4  ...       5
# 10  11    天津   63  172.7     18      -      -    4   30        4  ...       2
# ...

# %%
city_name_translation = {
    "北京": "Beijing",
    "上海": "Shanghai",
    "广州": "Guangzhou",
    "深圳": "Shenzhen",
    "成都": "Chengdu",
    "杭州": "Hangzhou",
    "厦门": "Xiamen",
    "济南": "Jinan",
    "南京": "Nanjing",
    "长沙": "Changsha",
    "重庆": "Chongqing",
    "武汉": "Wuhan",
    "青岛": "Qingdao",
    "西安": "Xi'an",
    "沈阳": "Shenyang",
    "郑州": "Zhengzhou",
    "合肥": "Hefei",
    "天津": "Tianjin",
    "长春": "Changchun",
    "宁波": "Ningbo",
    "南宁": "Nanning",
    "海口": "Haikou",
    "南昌": "Nanchang",
    "福州": "Fuzhou",
    "昆明": "Kunming",
    "哈尔滨": "Harbin",
    "贵阳": "Guiyang",
    "乌鲁木齐": "Urumqi",
    "呼和浩特": "Hohhot",
    "太原": "Taiyuan",
    "石家庄": "Shijiazhuang",
    "大连": "Dalian",
    "兰州": "Lanzhou",
    "银川": "Yinchuan",
    "西宁": "Xining",
    "拉萨":"Lhasa"
}

# %%
df2021.dtypes
# Out:
# 序号             object
# 城市             object
# 展览数量           object
# 展总面积           object
# 境内办展主体         object
# 境外展览数量         object
# 境外办展主体         object
# 展馆数量           object
# 展馆面积           object
# 政府社团研究机构       object
# 会展研究会员数        object
# IAEE组织成员(人)    object
# UFI成员(人)       object
# UFI认证项目        object
# TOP3项目         object
# TOP100项目       object
# 本科院校           object
# 专科院校           object
# 公众公司家          object
# 在读学生数量         object
# 待毕业学生数         object
# 线上展会数量         object
# 综合指数           object
# dtype: object

# %%
df2021.columns=[
    "Index",
    "City",
    "Number of Exhibitions",
    "Total Exhibition Area (10,000 sqm)",
    "Domestic Exhibition Organizers",
    "Number of Overseas Exhibitions",
    "Overseas Exhibition Organizers",
    "Number of Exhibition Halls",
    "Exhibition Hall Area (10,000 sqm)",
    "Government, Associations, Research Institutions",
    "Number of Exhibition Research Association Members",
    "Number of IAEE Members",
    "Number of UFI Members",
    "UFI Certified Projects",
    "Top 3 Projects",
    "Top 100 Projects",
    "Universities",
    "Higher Education",
    "Public Companies",
    "Number of  University Students ",
    "Number of Graduates",
    "Number of Online Exhibitions",
    "Aggregated Score"
]

# %%
df2021['City']=df2021.City.map(city_name_translation)
df2021
# Out:
# <ipython-input-30-41ba435dfaf4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2021['City']=df2021.City.map(city_name_translation)
#    Index          City Number of Exhibitions  \
# 0      1      Shanghai                   231
# 1      2       Beijing                   124
# 2      3     Guangzhou                   209
# 3      4      Shenzhen                   105
# 4      5       Chengdu                   242
# 5      6         Jinan                   106
# 6      7      Hangzhou                    38
# 7      8     Chongqing                    81
# 8      9      Changsha                   109
# 9     10       Nanjing                   161
# 10    11       Tianjin                    63
# ...

# %%
pd.read_csv('exhbition2022.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-7d02c0131679> in <module>
# ----> 1 pd.read_csv('exhbition2022.csv')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df2021.City.map(city_name_translation)
# Out:
# 0         Shanghai
# 1          Beijing
# 2        Guangzhou
# 3         Shenzhen
# 4          Chengdu
# 5            Jinan
# 6         Hangzhou
# 7        Chongqing
# 8         Changsha
# 9          Nanjing
# 10         Tianjin
# 11         Qingdao
# 12           Wuhan
# 13           Xi'an
# 14       Zhengzhou
# 15        Shenyang
# 16          Fuzhou
# 17           Hefei
# 18        Nanchang
# 19       Changchun
# 20          Xiamen
# 21          Ningbo
# 22          Harbin
# 23         Kunming
# 24         Guiyang
# 25    Shijiazhuang
# 26          Dalian
# 27         Nanning
# 28         Taiyuan
# 29          Haikou
# 30         Lanzhou
# 31          Hohhot
# 32          Urumqi
# 33        Yinchuan
# 34          Xining
# 35           Lhasa
# Name: City, dtype: object

# %%
df=pd.read_csv('exhibition2021.csv')
df.to_clipboard()

# %%
df.describe().to_clipboard()
